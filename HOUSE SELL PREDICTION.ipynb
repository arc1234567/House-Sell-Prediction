# %%
import pandas as pd
import numpy as np
df=pd.read_csv("train_.csv")
df["MiscVal"].isnull().sum()
# Out:
# 0

# %%
df2=df.drop(["Id","Alley","PoolQC","Fence","MiscFeature","SalePrice"],axis=1)
df2.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...               61             0
# 1    AllPub       FR2       Gtl      ...                0             0
# 2    AllPub    Inside       Gtl      ...               42             0
# 3    AllPub    Corner       Gtl      ...               35           272
# 4    AllPub       FR2       Gtl      ...               84             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
df2.fillna(df.mean, inplace=True)

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
df2['MSZoning']= label_encoder.fit_transform(df2['MSZoning'])
df2['Street']= label_encoder.fit_transform(df2['Street'])
df2["BsmtFinSF2"]= label_encoder.fit_transform(df2["BsmtFinSF2"])
df2["LowQualFinSF"]= label_encoder.fit_transform(df2["LowQualFinSF"])
df2["3SsnPorch"]= label_encoder.fit_transform(df2["3SsnPorch"])
df2["ScreenPorch"]= label_encoder.fit_transform(df2["ScreenPorch"])
df2["PoolArea"]= label_encoder.fit_transform(df2["PoolArea"])
df2["MiscVal"]= label_encoder.fit_transform(df2["MiscVal"])
df2['LotShape']= label_encoder.fit_transform(df2['LotShape'])
df2['LandContour']= label_encoder.fit_transform(df2['LandContour'])
df2['Utilities']= label_encoder.fit_transform(df2['Utilities'])
df2['LotConfig']= label_encoder.fit_transform(df2['LotConfig'])
df2['LandSlope']= label_encoder.fit_transform(df2['LandSlope'])
df2['Neighborhood']= label_encoder.fit_transform(df2['Neighborhood'])
df2['Condition1']= label_encoder.fit_transform(df2['Condition1'])
df2['Condition2']= label_encoder.fit_transform(df2['Condition2'])
df2['BldgType']= label_encoder.fit_transform(df2['BldgType'])
df2['HouseStyle']= label_encoder.fit_transform(df2['HouseStyle'])
df2['RoofStyle']= label_encoder.fit_transform(df2['RoofStyle'])
df2['RoofMatl']= label_encoder.fit_transform(df2['RoofMatl'])
df2['Exterior1st']= label_encoder.fit_transform(df2['Exterior1st'])
df2['Exterior2nd']= label_encoder.fit_transform(df2['Exterior2nd'])
#df2['MasVnrType']= label_encoder.fit_transform(df2['MasVnrType'])
df2['ExterQual']= label_encoder.fit_transform(df2['ExterQual'])
df2['ExterCond']= label_encoder.fit_transform(df2['ExterCond'])
df2['Foundation']= label_encoder.fit_transform(df2['Foundation'])
#df2['BsmtQual']= label_encoder.fit_transform(df2['BsmtQual'])
#df2['BsmtCond']= label_encoder.fit_transform(df2['BsmtCond'])
#df2['BsmtExposure']= label_encoder.fit_transform(df2['BsmtExposure'])
#df2['BsmtFinType1']= label_encoder.fit_transform(df2['BsmtFinType1'])
#df2['BsmtFinType2']= label_encoder.fit_transform(df2['BsmtFinType2'])
df2['Heating']= label_encoder.fit_transform(df2['Heating'])
df2['HeatingQC']= label_encoder.fit_transform(df2['HeatingQC'])
df2['CentralAir']= label_encoder.fit_transform(df2['CentralAir'])
#df2['Electrical']= label_encoder.fit_transform(df2['Electrical'])
df2['KitchenQual']= label_encoder.fit_transform(df2['KitchenQual'])
df2['Functional']= label_encoder.fit_transform(df2['Functional'])
#df2['FireplaceQu']= label_encoder.fit_transform(df2['FireplaceQu'])
#df2['GarageType']= label_encoder.fit_transform(df2['GarageType'])
#df2['GarageFinish']= label_encoder.fit_transform(df2['GarageFinish'])
#df2['GarageQual']= label_encoder.fit_transform(df2['GarageQual'])
#df2['GarageCond']= label_encoder.fit_transform(df2['GarageCond'])
df2['PavedDrive']= label_encoder.fit_transform(df2['PavedDrive'])
df2['SaleType']= label_encoder.fit_transform(df2['SaleType'])
df2['SaleCondition']= label_encoder.fit_transform(df2['SaleCondition'])

# %%
df2['MasVnrType'] = df2['MasVnrType'].replace('BrkCmn', 1)
df2['MasVnrType'] = df2['MasVnrType'].replace('BrkFace', 2)
df2['MasVnrType'] = df2['MasVnrType'].replace('CBlock', 3)
df2['MasVnrType'] = df2['MasVnrType'].replace('Stone', 4)
df2['MasVnrType'] = df2['MasVnrType'].replace('None', 5)

# %%
df2['BsmtQual'] = df2['BsmtQual'].replace('Ex', 5)
df2['BsmtQual'] = df2['BsmtQual'].replace('Gd', 4)
df2['BsmtQual'] = df2['BsmtQual'].replace('TA', 3)
df2['BsmtQual'] = df2['BsmtQual'].replace('Fa', 2)
df2['BsmtQual'] = df2['BsmtQual'].replace('Po', 1)
df2['BsmtQual'] = df2['BsmtQual'].replace('NA', 0)

# %%
df2['BsmtCond'] = df2['BsmtCond'].replace('Ex', 5)
df2['BsmtCond'] = df2['BsmtCond'].replace('Gd', 4)
df2['BsmtCond'] = df2['BsmtCond'].replace('TA', 3)
df2['BsmtCond'] = df2['BsmtCond'].replace('Fa', 2)
df2['BsmtCond'] = df2['BsmtCond'].replace('Po', 1)
df2['BsmtXCond'] = df2['BsmtCond'].replace('NA', 0)

# %%
df2['BsmtExposure'] = df2['BsmtExposure'].replace('Gd', 4)
df2['BsmtExposure'] = df2['BsmtExposure'].replace('Av', 3)
df2['BsmtExposure'] = df2['BsmtExposure'].replace('Mn', 2)
df2['BsmtExposure'] = df2['BsmtExposure'].replace('No', 1)
df2['BsmtExposure'] = df2['BsmtExposure'].replace('NA', 0)

# %%
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('GLQ', 6)
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('ALQ', 5)
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('BLQ', 4)
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('Rec', 3)
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('LwQ', 2)
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('Unf', 1)
df2['BsmtFinType1'] = df2['BsmtFinType1'].replace('NA', 0)

# %%
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('GLQ', 6)
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('ALQ', 5)
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('BLQ', 4)
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('Rec', 3)
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('LwQ', 2)
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('Unf', 1)
df2['BsmtFinType2'] = df2['BsmtFinType2'].replace('NA', 0)

# %%
df2['Electrical'] = df2['Electrical'].replace('SBrkr', 5)
df2['Electrical'] = df2['Electrical'].replace('FuseA', 4)
df2['Electrical'] = df2['Electrical'].replace('FuseF', 3)
df2['Electrical'] = df2['Electrical'].replace('FuseP', 2)
df2['Electrical'] = df2['Electrical'].replace('Mix', 1)

# %%
df2['FireplaceQu'] = df2['FireplaceQu'].replace('Ex', 5)
df2['FireplaceQu'] = df2['FireplaceQu'].replace('Gd', 4)
df2['FireplaceQu'] = df2['FireplaceQu'].replace('TA', 3)
df2['FireplaceQu'] = df2['FireplaceQu'].replace('Fa', 2)
df2['FireplaceQu'] = df2['FireplaceQu'].replace('Po', 1)
df2['FireplaceQu'] = df2['FireplaceQu'].replace('NA', 0)

# %%
df2['GarageType'] = df2['GarageType'].replace('2Types', 6)
df2['GarageType'] = df2['GarageType'].replace('Attchd', 5)
df2['GarageType'] = df2['GarageType'].replace('Basment', 4)
df2['GarageType'] = df2['GarageType'].replace('BuiltIn', 3)
df2['GarageType'] = df2['GarageType'].replace('CarPort', 2)
df2['GarageType'] = df2['GarageType'].replace('Detchd', 1)
df2['GarageType'] = df2['GarageType'].replace('NA', 0)

# %%
df2['GarageFinish'] = df2['GarageFinish'].replace('Fin', 3)
df2['GarageFinish'] = df2['GarageFinish'].replace('RFn', 2)
df2['GarageFinish'] = df2['GarageFinish'].replace('Unf', 1)
df2['GarageFinish'] = df2['GarageFinish'].replace('NA', 0)

# %%
df2['GarageQual'] = df2['GarageQual'].replace('Ex', 5)
df2['GarageQual'] = df2['GarageQual'].replace('Gd', 4)
df2['GarageQual'] = df2['GarageQual'].replace('TA', 3)
df2['GarageQual'] = df2['GarageQual'].replace('Fa', 2)
df2['GarageQual'] = df2['GarageQual'].replace('Po', 1)
df2['GarageQual'] = df2['GarageQual'].replace('NA', 0)

# %%
df2['GarageCond'] = df2['GarageCond'].replace('Ex', 5)
df2['GarageCond'] = df2['GarageCond'].replace('Gd', 4)
df2['GarageCond'] = df2['GarageCond'].replace('TA', 3)
df2['GarageCond'] = df2['GarageCond'].replace('Fa', 2)
df2['GarageCond'] = df2['GarageCond'].replace('Po', 1)
df2['GarageCond'] = df2['GarageCond'].replace('NA', 0)

# %%
x=df2[:]
y=df["SalePrice"]

# %%
df1=pd.read_csv("test_.csv")
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df3=df1.drop(["Id","Alley","PoolQC","Fence","MiscFeature"],axis=1)
df3.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...                0             0
# 1    AllPub    Corner       Gtl      ...               36             0
# 2    AllPub    Inside       Gtl      ...               34             0
# 3    AllPub    Inside       Gtl      ...               36             0
# 4    AllPub    Inside       Gtl      ...               82             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
df3.fillna(df3.mean, inplace=True)

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
le = preprocessing.LabelEncoder() 
#df3['MSZoning']= le.fit_transform(df3['MSZoning'])
df3['Street']= label_encoder.fit_transform(df3['Street'])
df3['LotShape']= label_encoder.fit_transform(df3['LotShape'])
df3['LandContour']= label_encoder.fit_transform(df3['LandContour'])
df3["BsmtFinSF2"]= label_encoder.fit_transform(df3["BsmtFinSF2"])
df3["LowQualFinSF"]= label_encoder.fit_transform(df3["LowQualFinSF"])
df3["3SsnPorch"]= label_encoder.fit_transform(df3["3SsnPorch"])
df3["ScreenPorch"]= label_encoder.fit_transform(df3["ScreenPorch"])
df3["PoolArea"]= label_encoder.fit_transform(df3["PoolArea"])
df3["MiscVal"]= label_encoder.fit_transform(df3["MiscVal"])
#df3['Utilities']= label_encoder.fit_transform(df3['Utilities'])
df3['LotConfig']= label_encoder.fit_transform(df3['LotConfig'])
df3['LandSlope']= label_encoder.fit_transform(df3['LandSlope'])
df3['Neighborhood']= label_encoder.fit_transform(df3['Neighborhood'])
df3['Condition1']= label_encoder.fit_transform(df3['Condition1'])
df3['Condition2']= label_encoder.fit_transform(df3['Condition2'])
df3['BldgType']= label_encoder.fit_transform(df3['BldgType'])
df3['HouseStyle']= label_encoder.fit_transform(df3['HouseStyle'])
df3['RoofStyle']= label_encoder.fit_transform(df3['RoofStyle'])
df3['RoofMatl']= label_encoder.fit_transform(df3['RoofMatl'])
#df3['Exterior1st']= label_encoder.fit_transform(df3['Exterior1st'])
#df3['Exterior2nd']= label_encoder.fit_transform(df3['Exterior2nd'])
#df2['MasVnrType']= label_encoder.fit_transform(df2['MasVnrType'])
df3['ExterQual']= label_encoder.fit_transform(df3['ExterQual'])
df3['ExterCond']= label_encoder.fit_transform(df3['ExterCond'])
df3['Foundation']= label_encoder.fit_transform(df3['Foundation'])
#df2['BsmtQual']= label_encoder.fit_transform(df2['BsmtQual'])
#df2['BsmtCond']= label_encoder.fit_transform(df2['BsmtCond'])
#df2['BsmtExposure']= label_encoder.fit_transform(df2['BsmtExposure'])
#df2['BsmtFinType1']= label_encoder.fit_transform(df2['BsmtFinType1'])
#df2['BsmtFinType2']= label_encoder.fit_transform(df2['BsmtFinType2'])
df3['Heating']= label_encoder.fit_transform(df3['Heating'])
df3['HeatingQC']= label_encoder.fit_transform(df3['HeatingQC'])
df3['CentralAir']= label_encoder.fit_transform(df3['CentralAir'])
#df2['Electrical']= label_encoder.fit_transform(df2['Electrical'])
#df3['KitchenQual']= label_encoder.fit_transform(df3['KitchenQual'])
#df3['Functional']= label_encoder.fit_transform(df3['Functional'])
#df2['FireplaceQu']= label_encoder.fit_transform(df2['FireplaceQu'])
#df2['GarageType']= label_encoder.fit_transform(df2['GarageType'])
#df2['GarageFinish']= label_encoder.fit_transform(df2['GarageFinish'])
#df2['GarageQual']= label_encoder.fit_transform(df2['GarageQual'])
#df2['GarageCond']= label_encoder.fit_transform(df2['GarageCond'])
df3['PavedDrive']= label_encoder.fit_transform(df3['PavedDrive'])
#df3['SaleType']= label_encoder.fit_transform(df3['SaleType'])
df3['SaleCondition']= label_encoder.fit_transform(df3['SaleCondition'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2a28f65e119a> in <module>
#       7 df3['LotShape']= label_encoder.fit_transform(df3['LotShape'])
#       8 df3['LandContour']= label_encoder.fit_transform(df3['LandContour'])
# ----> 9 df3["BsmtFinSF2"]= label_encoder.fit_transform(df3["BsmtFinSF2"])
#      10 df3["LowQualFinSF"]= label_encoder.fit_transform(df3["LowQualFinSF"])
#      11 df3["3SsnPorch"]= label_encoder.fit_transform(df3["3SsnPorch"])
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     234         """
#     235         y = column_or_1d(y, warn=True)
# --> 236         self.classes_, y = _encode(y, encode=True)
#     237         return y
#     238
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     106     """
# ...

# %%
df3['MSZoning'] = df3['MSZoning'].replace('A', 8)
df3['MSZoning'] = df3['MSZoning'].replace('C', 7)
df3['MSZoning'] = df3['MSZoning'].replace('I', 6)
df3['MSZoning'] = df3['MSZoning'].replace('RH', 5)
df3['MSZoning'] = df3['MSZoning'].replace('FV', 4)
df3['MSZoning'] = df3['MSZoning'].replace('RL', 3)
df3['MSZoning'] = df3['MSZoning'].replace('RP', 2)
df3['MSZoning'] = df3['MSZoning'].replace('RM', 1)
df3['MSZoning'] = df3['MSZoning'].replace('C (all)', 0)

# %%
df3['Utilities'] = df3['Utilities'].replace('AllPub', 4)
df3['Utilities'] = df3['Utilities'].replace('NoSewr', 3)
df3['Utilities'] = df3['Utilities'].replace('NoSeWa', 2)
df3['Utilities'] = df3['Utilities'].replace('ELO', 1)

# %%
df3['Exterior1st'] = df3['Exterior1st'].replace('AsbShng', 16)
df3['Exterior1st'] = df3['Exterior1st'].replace('AsphShn', 15)
df3['Exterior1st'] = df3['Exterior1st'].replace('BrkComm', 14)
df3['Exterior1st'] = df3['Exterior1st'].replace('BrkFace', 13)
df3['Exterior1st'] = df3['Exterior1st'].replace('CemntBd', 12)
df3['Exterior1st'] = df3['Exterior1st'].replace('HdBoard',11)
df3['Exterior1st'] = df3['Exterior1st'].replace('ImStucc', 10)
df3['Exterior1st'] = df3['Exterior1st'].replace('MetalSd', 9)
df3['Exterior1st'] = df3['Exterior1st'].replace('Other', 8)
df3['Exterior1st'] = df3['Exterior1st'].replace('Plywood', 7)
df3['Exterior1st'] = df3['Exterior1st'].replace('PreCast', 6)
df3['Exterior1st'] = df3['Exterior1st'].replace('Stone', 5)
df3['Exterior1st'] = df3['Exterior1st'].replace('Stucco', 4)
df3['Exterior1st'] = df3['Exterior1st'].replace('VinylSd', 3)
df3['Exterior1st'] = df3['Exterior1st'].replace('Wd Sdng', 2)
df3['Exterior1st'] = df3['Exterior1st'].replace('WdShing', 1)
df3['Exterior1st'] = df3['Exterior1st'].replace('CBlock', 0)

# %%
df3['Exterior2nd'] = df3['Exterior2nd'].replace('AsbShng', 16)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('AsphShn', 15)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('BrkComm', 14)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('BrkFace', 13)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('CemntBd', 12)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('HdBoard',11)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('ImStucc', 10)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('MetalSd', 9)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Other', 8)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Plywood', 7)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('PreCast', 6)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Stone', 5)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Stucco', 4)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('VinylSd', 3)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Wd Sdng', 2)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('WdShing', 1)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('CBlock', 17)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('CmentBd', 18)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Wd Shng', 19)
df3['Exterior2nd'] = df3['Exterior2nd'].replace('Brk Cmn', 20)

# %%
df3['KitchenQual'] = df3['KitchenQual'].replace('Ex', 5)
df3['KitchenQual'] = df3['KitchenQual'].replace('Gd', 4)
df3['KitchenQual'] = df3['KitchenQual'].replace('TA', 3)
df3['KitchenQual'] = df3['KitchenQual'].replace('Fa', 2)
df3['KitchenQual'] = df3['KitchenQual'].replace('Po', 1)

# %%
df3['Functional'] = df3['Functional'].replace('Typ', 8)
df3['Functional'] = df3['Functional'].replace('Min1', 7)
df3['Functional'] = df3['Functional'].replace('Min2', 6)
df3['Functional'] = df3['Functional'].replace('Mod', 5)
df3['Functional'] = df3['Functional'].replace('Maj1', 4)
df3['Functional'] = df3['Functional'].replace('Maj2', 3)
df3['Functional'] = df3['Functional'].replace('Sev', 2)
df3['Functional'] = df3['Functional'].replace('Sal', 1)

# %%
df3['SaleType'] = df3['SaleType'].replace('WD', 10)
df3['SaleType'] = df3['SaleType'].replace('CWD', 9)
df3['SaleType'] = df3['SaleType'].replace('VWD', 8)
df3['SaleType'] = df3['SaleType'].replace('New', 7)
df3['SaleType'] = df3['SaleType'].replace('COD', 6)
df3['SaleType'] = df3['SaleType'].replace('Con', 5)
df3['SaleType'] = df3['SaleType'].replace('ConLw', 4)
df3['SaleType'] = df3['SaleType'].replace('ConLI', 3)
df3['SaleType'] = df3['SaleType'].replace('ConLD', 2)
df3['SaleType'] = df3['SaleType'].replace('Oth', 1)

# %%
df3['MasVnrType'] = df3['MasVnrType'].replace('BrkCmn', 1)
df3['MasVnrType'] = df3['MasVnrType'].replace('BrkFace', 2)
df3['MasVnrType'] = df3['MasVnrType'].replace('CBlock', 3)
df3['MasVnrType'] = df3['MasVnrType'].replace('Stone', 4)
df3['MasVnrType'] = df3['MasVnrType'].replace('None', 5)

# %%
df3['BsmtQual'] = df3['BsmtQual'].replace('Ex', 5)
df3['BsmtQual'] = df3['BsmtQual'].replace('Gd', 4)
df3['BsmtQual'] = df3['BsmtQual'].replace('TA', 3)
df3['BsmtQual'] = df3['BsmtQual'].replace('Fa', 2)
df3['BsmtQual'] = df3['BsmtQual'].replace('Po', 1)
df3['BsmtQual'] = df3['BsmtQual'].replace('NA', 0)

# %%
df3['BsmtCond'] = df3['BsmtCond'].replace('Ex', 5)
df3['BsmtCond'] = df3['BsmtCond'].replace('Gd', 4)
df3['BsmtCond'] = df3['BsmtCond'].replace('TA', 3)
df3['BsmtCond'] = df3['BsmtCond'].replace('Fa', 2)
df3['BsmtCond'] = df3['BsmtCond'].replace('Po', 1)
df3['BsmtXCond'] = df3['BsmtCond'].replace('NA', 0)

# %%
df3['BsmtExposure'] = df3['BsmtExposure'].replace('Gd', 4)
df3['BsmtExposure'] = df3['BsmtExposure'].replace('Av', 3)
df3['BsmtExposure'] = df3['BsmtExposure'].replace('Mn', 2)
df3['BsmtExposure'] = df3['BsmtExposure'].replace('No', 1)
df3['BsmtExposure'] = df3['BsmtExposure'].replace('NA', 0)

# %%
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('GLQ', 6)
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('ALQ', 5)
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('BLQ', 4)
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('Rec', 3)
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('LwQ', 2)
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('Unf', 1)
df3['BsmtFinType1'] = df3['BsmtFinType1'].replace('NA', 0)

# %%
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('GLQ', 6)
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('ALQ', 5)
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('BLQ', 4)
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('Rec', 3)
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('LwQ', 2)
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('Unf', 1)
df3['BsmtFinType2'] = df3['BsmtFinType2'].replace('NA', 0)

# %%
df3['Electrical'] = df3['Electrical'].replace('SBrkr', 5)
df3['Electrical'] = df3['Electrical'].replace('FuseA', 4)
df3['Electrical'] = df3['Electrical'].replace('FuseF', 3)
df3['Electrical'] = df3['Electrical'].replace('FuseP', 2)
df3['Electrical'] = df3['Electrical'].replace('Mix', 1)

# %%
df3['FireplaceQu'] = df3['FireplaceQu'].replace('Ex', 5)
df3['FireplaceQu'] = df3['FireplaceQu'].replace('Gd', 4)
df3['FireplaceQu'] = df3['FireplaceQu'].replace('TA', 3)
df3['FireplaceQu'] = df3['FireplaceQu'].replace('Fa', 2)
df3['FireplaceQu'] = df3['FireplaceQu'].replace('Po', 1)
df3['FireplaceQu'] = df3['FireplaceQu'].replace('NA', 0)

# %%
df3['GarageType'] = df3['GarageType'].replace('2Types', 6)
df3['GarageType'] = df3['GarageType'].replace('Attchd', 5)
df3['GarageType'] = df3['GarageType'].replace('Basment', 4)
df3['GarageType'] = df3['GarageType'].replace('BuiltIn', 3)
df3['GarageType'] = df3['GarageType'].replace('CarPort', 2)
df3['GarageType'] = df3['GarageType'].replace('Detchd', 1)
df3['GarageType'] = df3['GarageType'].replace('NA', 0)

# %%
df3['GarageFinish'] = df3['GarageFinish'].replace('Fin', 3)
df3['GarageFinish'] = df3['GarageFinish'].replace('RFn', 2)
df3['GarageFinish'] = df3['GarageFinish'].replace('Unf', 1)
df3['GarageFinish'] = df3['GarageFinish'].replace('NA', 0)

# %%
df3['GarageQual'] = df3['GarageQual'].replace('Ex', 5)
df3['GarageQual'] = df3['GarageQual'].replace('Gd', 4)
df3['GarageQual'] = df3['GarageQual'].replace('TA', 3)
df3['GarageQual'] = df3['GarageQual'].replace('Fa', 2)
df3['GarageQual'] = df3['GarageQual'].replace('Po', 1)
df3['GarageQual'] = df3['GarageQual'].replace('NA', 0)

# %%
df3['GarageCond'] = df3['GarageCond'].replace('Ex', 5)
df3['GarageCond'] = df3['GarageCond'].replace('Gd', 4)
df3['GarageCond'] = df3['GarageCond'].replace('TA', 3)
df3['GarageCond'] = df3['GarageCond'].replace('Fa', 2)
df3['GarageCond'] = df3['GarageCond'].replace('Po', 1)
df3['GarageCond'] = df3['GarageCond'].replace('NA', 0)

# %%
import xgboost as xgb
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)
xg_reg.fit(x,y)
# Out:
# [15:55:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\ARIJIT ROYCHAUDHURY\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\ARIJIT ROYCHAUDHURY\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=10,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
# ...

# %%
x_test=df3[:]

# %%
y_pred= xg_reg.predict(x_test)

# %%
submission_5 = pd.DataFrame({'Id':df1['Id'],'SalePrice':y_pred})

# %%
submission_5.to_csv("RES1.csv",index=False)

# %%
submission_5.head()
# Out:
#      Id      SalePrice
# 0  1461   79873.328125
# 1  1462   93292.320312
# 2  1463  114318.718750
# 3  1464  117589.828125
# 4  1465  125535.593750
